# %% [markdown]
# In \[1\]:
#
#     # checking the type
#     type([1 , 34 , 3])
#
# Out\[1\]:
#
#     list
#
# In \[2\]:
#
#     # checking the type of 1st element in the above created list
#     type(1)
#
# Out\[2\]:
#
#     int
#
# In \[3\]:
#
#     # checking the type of the string
#     type('the cat is yellow')
#
# Out\[3\]:
#
#     str
#
# In \[4\]:
#
#     # checking the type of an element
#     type({"dog : 1" , "cat :2"})
#
# Out\[4\]:
#
#     set
#
# In \[8\]:
#
#     # operation on sorting function
#     # performing the ascendind order operation
#     Ratings = [10 ,9,6,5,10 ,8,9,6,2]
#     Ratings.sort ()
#
# In \[9\]:
#
#     # printing the ratings
#     # the ratings are printed in ascending order
#     Ratings
#
# Out\[9\]:
#
#     [2, 5, 6, 6, 8, 9, 9, 10, 10]
#
# In \[10\]:
#
#     # reverse sorting or descending order
#     # performing the reverse sorting
#     Ratings = [2,5,6,6,8,9,9,10,10]
#     Ratings.reverse()
#
# In \[11\]:
#
#     # printing the ratings
#     # the ratings are printed in decsencing order
#     Ratings
#
# Out\[11\]:
#
#     [10, 10, 9, 9, 8, 6, 6, 5, 2]
#
# In \[ \]:
